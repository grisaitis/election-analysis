# %%
import tabula

# %%
dfs = tabula.read_pdf("./orange_precinct_2020.pdf", pages=list(range(1, 56)))
# Out:
# Got stderr: Nov 08, 2020 2:22:17 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: Your current java version is: 1.8.0_144
# Nov 08, 2020 2:22:17 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO: To get higher rendering speed on old java 1.8 or 9 versions,
# Nov 08, 2020 2:22:17 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   update to the latest 1.8 or 9 version (>= 1.8.0_191 or >= 9.0.4),
# Nov 08, 2020 2:22:17 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or
# Nov 08, 2020 2:22:17 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   use the option -Dsun.java2d.cmm=sun.java2d.cmm.kcms.KcmsServiceProvider
# Nov 08, 2020 2:22:17 AM org.apache.pdfbox.rendering.PDFRenderer suggestKCMS
# INFO:   or call System.setProperty("sun.java2d.cmm", "sun.java2d.cmm.kcms.KcmsServiceProvider")

# %%
import pandas as pd

# %%
df = pd.concat(dfs)
df = df.iloc[:-5]
df
# Out:
#                               Precinct - Contest Contest Party  \
# 0   President and Vice President - PRECINCT: 101           GEN
# 1   President and Vice President - PRECINCT: 101           GEN
# 2   President and Vice President - PRECINCT: 101           GEN
# 3   President and Vice President - PRECINCT: 101           GEN
# 4   President and Vice President - PRECINCT: 101           GEN
# ..                                           ...           ...
# 35  President and Vice President - PRECINCT: 634           GEN
# 36  President and Vice President - PRECINCT: 634           GEN
# 37  President and Vice President - PRECINCT: 634           GEN
# 38  President and Vice President - PRECINCT: 634           GEN
# 39  President and Vice President - PRECINCT: 634           GEN
#
#    Precincts Reporting  Total Eligible                   Candidate  \
# 0           247 of 247          866460             Donald J. Trump
# 1           247 of 247          866460             Joseph R. Biden
# ...

# %%
df.loc[:, "countypct"] = df["Precinct - Contest"].apply(lambda text: "ORA" + text[-3:])
df
# Out:
#                               Precinct - Contest Contest Party  \
# 0   President and Vice President - PRECINCT: 101           GEN
# 1   President and Vice President - PRECINCT: 101           GEN
# 2   President and Vice President - PRECINCT: 101           GEN
# 3   President and Vice President - PRECINCT: 101           GEN
# 4   President and Vice President - PRECINCT: 101           GEN
# ..                                           ...           ...
# 35  President and Vice President - PRECINCT: 634           GEN
# 36  President and Vice President - PRECINCT: 634           GEN
# 37  President and Vice President - PRECINCT: 634           GEN
# 38  President and Vice President - PRECINCT: 634           GEN
# 39  President and Vice President - PRECINCT: 634           GEN
#
#    Precincts Reporting  Total Eligible                   Candidate  \
# 0           247 of 247          866460             Donald J. Trump
# 1           247 of 247          866460             Joseph R. Biden
# ...

# %%
orange_2020 = df.pivot(
    index="countypct",
    columns="Candidate",
    values="Total Votes"
)

orange_2020
# Out:
# Candidate  Don Blankenship  Donald J. Trump  Gloria La Riva  Howie Hawkins  \
# countypct
# ORA101                   3             1244               2              6
# ORA102                   0              887               2              2
# ORA103                   1             1004               0              1
# ORA104                   0             1332               5              8
# ORA105                   0              555               2              0
# ...                    ...              ...             ...            ...
# ORA630                   1              378               0              4
# ORA631                   0                0               0              0
# ORA632                   1              638               4              2
# ORA633                   0              355               7              7
# ORA634                   2              272               1              5
#
# Candidate  Jo Jorgensen  Joseph R. Biden  OVER VOTES  \
# ...

# %%
orange_2020.to_csv("./orange_2020_from_pdf.csv")
